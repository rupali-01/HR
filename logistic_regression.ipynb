# %% [markdown]
# <a href="https://colab.research.google.com/github/rupali-01/HR/blob/main/logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Predicting if a person would buy life insurnace based on his age using logistic regression**
#
# Above is a binary logistic regression problem as there are only two possible outcomes (i.e. if person buys insurance or he/she doesn't).

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-57c96e71-b667-440e-a4df-8fd06b94cbd1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-57c96e71-b667-440e-a4df-8fd06b94cbd1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv(list(uploaded.keys())[0])

# %%
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df.age,df.bought_insurance,marker='+',color='blue')

# %%
df.shape
# Out:
# (27, 2)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['age']],df.bought_insurance,train_size=0.8)

# %%
X_test
# Out:
#     age
# 22   40
# 11   28
# 15   55
# 4    46
# 19   18
# 18   19

# %%
X_train
# Out:
#     age
# 0    22
# 3    52
# 7    60
# 21   26
# 1    25
# 17   58
# 26   23
# 25   54
# 8    62
# 16   25
# 13   29
# 5    56
# 24   50
# 14   49
# 12   27
# 6    55
# 23   45
# 2    47
# 10   18
# 20   21
# 9    61

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
X_test
# Out:
#     age
# 22   40
# 11   28
# 15   55
# 4    46
# 19   18
# 18   19

# %%
y_test
# Out:
# 22    1
# 11    0
# 15    1
# 4     1
# 19    0
# 18    0
# Name: bought_insurance, dtype: int64

# %%
model.predict(X_test)
# Out:
# array([0, 0, 1, 1, 0, 0])

# %%
model.score(X_test,y_test)
# Out:
# 0.8333333333333334

# %%
X_test
# Out:
#     age
# 22   40
# 11   28
# 15   55
# 4    46
# 19   18
# 18   19

# %%
y_predicted = model.predict(X_test)

# %%
y_predicted
# Out:
# array([0, 0, 1, 1, 0, 0])

# %%
y_test
# Out:
# 22    1
# 11    0
# 15    1
# 4     1
# 19    0
# 18    0
# Name: bought_insurance, dtype: int64

# %%
model.predict_proba(X_test)
# Out:
# array([[0.51080029, 0.48919971],
#        [0.81453828, 0.18546172],
#        [0.14773236, 0.85226764],
#        [0.33736148, 0.66263852],
#        [0.93565035, 0.06434965],
#        [0.92805551, 0.07194449]])

# %%
model.score(X_test,y_test)
# Out:
# 0.8333333333333334

# %%
y_predicted
# Out:
# array([0, 0, 1, 1, 0, 0])

# %%
X_test
# Out:
#     age
# 22   40
# 11   28
# 15   55
# 4    46
# 19   18
# 18   19

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-30175390-7b15-43a3-92ea-6fe648a0adb5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-30175390-7b15-43a3-92ea-6fe648a0adb5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df1 = pd.read_csv(list(uploaded.keys())[0])
df1
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %% [markdown]
# 1. Now do some exploratory data analysis to figure out which variables have direct and clear impact on employee retention (i.e. whether they leave the company or continue to work).
#
# 2. Plot bar charts showing impact of employee salaries on retention.
#
# 3. Plot bar charts showing corelation between department and employee retention.
#
# 4. Now build logistic regression model using variables that were narrowed down in step 1.
#
# 5. Measure the accuracy of the model
